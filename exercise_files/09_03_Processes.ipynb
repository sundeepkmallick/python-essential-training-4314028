# %%
from multiprocess import Process
import time
import threading

# %% [markdown]
# ## Processes

# %%
def longSquare(num, results):
    time.sleep(1)
    print(num**2)
    print('Finished computing!')

results = {}
processes = [Process(target=longSquare, args=(n,results)) for n in range(0, 10)]
[p.start() for p in processes]
[p.join() for p in processes]
# Out:
# 014916
#
# 25
# 36
#
# 49Finished computing!Finished computing!Finished computing!
# 6481Finished computing!
# Finished computing!
#
#
#
# Finished computing!
#
#
# Finished computing!
# Finished computing!
# Finished computing!Finished computing!
# [None, None, None, None, None, None, None, None, None, None]

# %%
results = {}
threads = [threading.Thread(target=longSquare, args=(n, results)) for n in range(0, 10)]
[t.start() for t in threads]
[t.join() for t in threads]
print(results)
# Out:
# 19
# Finished computing!
# 4
# Finished computing!
# 16
# Finished computing!
# 25
# Finished computing!
# 64
# Finished computing!
# 81
# Finished computing!
# 0
# Finished computing!
# 36
# Finished computing!
# 49
# Finished computing!
#
# Finished computing!
# {}
