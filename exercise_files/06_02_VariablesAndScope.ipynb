# %% [markdown]
# ## Function Scope

# %%
def performOperation(*args, **kwargs):
    print(args)
    print(kwargs)

performOperation(1, 2, operation='sum',)
# Out:
# (1, 2)
# {'operation': 'sum'}

# %% [markdown]
# ### locals()

# %%
def performOperation(num1, num2, operation='sum'):
    print(locals())
    
performOperation(1, 2, operation='multiply')
print(num1)
# Out:
# {'num1': 1, 'num2': 2, 'operation': 'multiply'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       2     print(locals())
#       4 performOperation(1, 2, operation='multiply')
# ----> 5 print(num1)
#
# NameError: name 'num1' is not defined

# %% [markdown]
# ### globals()

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   "def performOperation(*args, **kwargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum')",
#   "def performOperation(*args, **kwargs, ***twargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum', ('abc',2))",
#   "def performOperation(*args, **kwargs, **twargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum', ('abc',2))",
#   "def performOperation(*args, **kwargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum', ('abc',2))",
#   "def performOperation(*args, **kwargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum', 5)",
#   "def performOperation(*args, **kwargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum', ['a', 'b'])",
#   "def performOperation(*args, **kwargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum',)",
#   "def performOperation(num1, num2, operation='sum'):\n    print(locals())\n\nperformOperation(1, 2, operation='multiply')\nprint(num1)",
#   'globals()'],
#  '_oh': {},
#  '_dh': [PosixPath('/Users/MLS6KOR/PythonProjects/python-essential-training-4314028/exercise_files')],
#  'In': ['',
#   "def performOperation(*args, **kwargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum')",
#   "def performOperation(*args, **kwargs, ***twargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum', ('abc',2))",
#   "def performOperation(*args, **kwargs, **twargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum', ('abc',2))",
#   "def performOperation(*args, **kwargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum', ('abc',2))",
#   "def performOperation(*args, **kwargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum', 5)",
#   "def performOperation(*args, **kwargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum', ['a', 'b'])",
#   "def performOperation(*args, **kwargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum',)",
#   "def performOperation(num1, num2, operation='sum'):\n    print(locals())\n\nperformOperation(1, 2, operation='multiply')\nprint(num1)",
#   'globals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107429550>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x10742b230>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x10742b230>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '__session__': '/Users/MLS6KOR/PythonProjects/python-essential-training-4314028/exercise_files/06_02_VariablesAndScope.ipynb',
#  '_i': "def performOperation(num1, num2, operation='sum'):\n    print(locals())\n    \nperformOperation(1, 2, operation='multiply')\nprint(num1)",
#  '_ii': "def performOperation(*args, **kwargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum',)",
#  '_iii': "def performOperation(*args, **kwargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum', ['a', 'b'])",
#  '_i1': "def performOperation(*args, **kwargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum')",
#  'performOperation': <function __main__.performOperation(num1, num2, operation='sum')>,
#  '_i2': "def performOperation(*args, **kwargs, ***twargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum', ('abc',2))",
#  '_i3': "def performOperation(*args, **kwargs, **twargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum', ('abc',2))",
#  '_i4': "def performOperation(*args, **kwargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum', ('abc',2))",
#  '_i5': "def performOperation(*args, **kwargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum', 5)",
#  '_i6': "def performOperation(*args, **kwargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum', ['a', 'b'])",
#  '_i7': "def performOperation(*args, **kwargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum',)",
#  '_i8': "def performOperation(num1, num2, operation='sum'):\n    print(locals())\n    \nperformOperation(1, 2, operation='multiply')\nprint(num1)",
#  '_i9': 'globals()'}

# %% [markdown]
# ### Global and Local scope

# %%
message = 'Some global data'

def function1(varA, varB):
    print(message)
    print(locals())
    
    
def function2(varC, varB):
    print(message)
    print(locals())
    
function1(1, 2)
function2(3, 4)
# Out:
# Some global data
# {'varA': 1, 'varB': 2}
# Some global data
# {'varC': 3, 'varB': 4}

# %%
message = 'Some global data'
varA = 2
def function1(varA, varB):
    message = 'Some local data'
    print(varA)
    print(message)
    print(locals())
    
    
def function2(varC, varB):
    print(varA)
    print(message)
    print(locals())
    
function1(1, 2)
function2(3, 4)
# Out:
# 1
# Some local data
# {'varA': 1, 'varB': 2, 'message': 'Some local data'}
# 2
# Some global data
# {'varC': 3, 'varB': 4}

# %%
def function1(varA, varB):
    message = 'Some local data'
    print(varA)
    def inner_function(varA, varB):
        print(f'inner_function local scope: {locals()}')
        
    inner_function(123, 456)
    

function1(1, 2)
# Out:
# 1
# inner_function local scope: {'varA': 123, 'varB': 456}

# %%
def function1(varA, varB):
    message = 'Some local data'
    print(varA)
    def inner_function(varA, varB):
        print(f'inner_function local scope: {locals()}')
    
    print(locals())
    inner_function(123, 456)
    

function1(1, 2)
# Out:
# 1
# {'varA': 1, 'varB': 2, 'message': 'Some local data', 'inner_function': <function function1.<locals>.inner_function at 0x107be77f0>}
# inner_function local scope: {'varA': 123, 'varB': 456}
