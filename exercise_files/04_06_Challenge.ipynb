# %% [markdown]
# ## ASCII Art Encoding
#
# Write a function "encodeString" that will encode a string like 'AAAAABBBBAAA' as a list of tuples: [('A', 5), ('B', 4), ('A', 3)] meaning that the string has "5 A's, followed by 4 B's, followed by 3 A's"
#
# Then use that function to compress a string containing "ASCII Art" (https://en.wikipedia.org/wiki/ASCII_art)
#
# Write a corresponding function "decodeString" that will take in a list of tuples and print the original string.

# %%
def encodeString(stringVal):
    stringTupleList = []
    tupleChar = ''
    tupleCount = 1
    for i, char in enumerate(stringVal):
        if(i == len(stringVal) - 1):
            #print(i, stringVal[len(stringVal) - 1])
            stringTupleList.append((stringVal[i], tupleCount))
        else:    
            #print(i, stringVal[i], i+1, stringVal[i+1])
            if(stringVal[i] == stringVal[i+1]):
                #print('same as after')
                tupleCount = tupleCount + 1
                #print(stringVal[i], tupleCount)
            else:
                #print('not same as after')                
                stringTupleList.append((stringVal[i], tupleCount))
                tupleCount = 1
    print(stringTupleList)
    return stringTupleList

def decodeString(encodedList):
    encodedString = ''
    for i, item in enumerate(encodedList):
        tupleChar = item[0]
        tupleCount = item[1]
        while(tupleCount > 0):
            encodedString = encodedString + tupleChar
            tupleCount = tupleCount - 1
          
    print(encodedString)        
    return encodedString

# %%
art = '''

                                                                                
                                                                                
                               %%%%%%%%%%%%%%%%%%%                              
                        %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%                       
                    %%%%%%%%                         %%%%%%%%                   
                %%%%%%%                                   %%%%%%                
              %%%%%%                                         %%%%%%             
           %%%%%%                                               %%%%%           
          %%%%%                                                   %%%%%         
        %%%%%                                                       %%%%%       
       %%%%                 %%%%%              %%%%%                  %%%%      
      %%%%                 %%%%%%%            %%%%%%%                  %%%%     
     %%%%                  %%%%%%%            %%%%%%%                   %%%%    
    %%%%                   %%%%%%%            %%%%%%%                    %%%%   
    %%%%                    %%%%%              %%%%%                     %%%%   
   %%%%                                                                   %%%%  
   %%%%                                                                   %%%%  
   %%%%                                                                   %%%%  
   %%%%                                                      %%%%        %%%%   
    %%%%       %%%%%%                                        %%%%%       %%%%   
    %%%%         %%%%                                       %%%%        %%%%    
     %%%%         %%%%                                     %%%%         %%%%    
      %%%%         %%%%%                                  %%%%         %%%%     
       %%%%%         %%%%%                             %%%%%         %%%%%      
        %%%%%          %%%%%%                        %%%%%          %%%%        
          %%%%%           %%%%%%%               %%%%%%%           %%%%%         
            %%%%%             %%%%%%%%%%%%%%%%%%%%%             %%%%%           
              %%%%%%%                                        %%%%%              
                 %%%%%%%                                 %%%%%%%                
                     %%%%%%%%%                     %%%%%%%%%                    
                          %%%%%%%%%%%%%%%%%%%%%%%%%%%%%                         
                                   %%%%%%%%%%%%                                 
                                                                                
                                                                                 

'''

# %%
encodedString = encodeString(art)
# Out:
# [('\n', 4), (' ', 31), ('%', 19), (' ', 30), ('\n', 1), (' ', 24), ('%', 33), (' ', 23), ('\n', 1), (' ', 20), ('%', 8), (' ', 25), ('%', 8), (' ', 19), ('\n', 1), (' ', 16), ('%', 7), (' ', 35), ('%', 6), (' ', 16), ('\n', 1), (' ', 14), ('%', 6), (' ', 41), ('%', 6), (' ', 13), ('\n', 1), (' ', 11), ('%', 6), (' ', 47), ('%', 5), (' ', 11), ('\n', 1), (' ', 10), ('%', 5), (' ', 51), ('%', 5), (' ', 9), ('\n', 1), (' ', 8), ('%', 5), (' ', 55), ('%', 5), (' ', 7), ('\n', 1), (' ', 7), ('%', 4), (' ', 17), ('%', 5), (' ', 14), ('%', 5), (' ', 18), ('%', 4), (' ', 6), ('\n', 1), (' ', 6), ('%', 4), (' ', 17), ('%', 7), (' ', 12), ('%', 7), (' ', 18), ('%', 4), (' ', 5), ('\n', 1), (' ', 5), ('%', 4), (' ', 18), ('%', 7), (' ', 12), ('%', 7), (' ', 19), ('%', 4), (' ', 4), ('\n', 1), (' ', 4), ('%', 4), (' ', 19), ('%', 7), (' ', 12), ('%', 7), (' ', 20), ('%', 4), (' ', 3), ('\n', 1), (' ', 4), ('%', 4), (' ', 20), ('%', 5), (' ', 14), ('%', 5), (' ', 21), ('%', 4), (' ', 3), ('\n', 1), (' ', 3), ('%', 4), (' ', 67), ('%', 4), (' ', 2), ('\n', 1), (' ', 3), ('%', 4), (' ', 67), ('%', 4), (' ', 2), ('\n', 1), (' ', 3), ('%', 4), (' ', 67), ('%', 4), (' ', 2), ('\n', 1), (' ', 3), ('%', 4), (' ', 54), ('%', 4), (' ', 8), ('%', 4), (' ', 3), ('\n', 1), (' ', 4), ('%', 4), (' ', 7), ('%', 6), (' ', 40), ('%', 5), (' ', 7), ('%', 4), (' ', 3), ('\n', 1), (' ', 4), ('%', 4), (' ', 9), ('%', 4), (' ', 39), ('%', 4), (' ', 8), ('%', 4), (' ', 4), ('\n', 1), (' ', 5), ('%', 4), (' ', 9), ('%', 4), (' ', 37), ('%', 4), (' ', 9), ('%', 4), (' ', 4), ('\n', 1), (' ', 6), ('%', 4), (' ', 9), ('%', 5), (' ', 34), ('%', 4), (' ', 9), ('%', 4), (' ', 5), ('\n', 1), (' ', 7), ('%', 5), (' ', 9), ('%', 5), (' ', 29), ('%', 5), (' ', 9), ('%', 5), (' ', 6), ('\n', 1), (' ', 8), ('%', 5), (' ', 10), ('%', 6), (' ', 24), ('%', 5), (' ', 10), ('%', 4), (' ', 8), ('\n', 1), (' ', 10), ('%', 5), (' ', 11), ('%', 7), (' ', 15), ('%', 7), (' ', 11), ('%', 5), (' ', 9), ('\n', 1), (' ', 12), ('%', 5), (' ', 13), ('%', 21), (' ', 13), ('%', 5), (' ', 11), ('\n', 1), (' ', 14), ('%', 7), (' ', 40), ('%', 5), (' ', 14), ('\n', 1), (' ', 17), ('%', 7), (' ', 33), ('%', 7), (' ', 16), ('\n', 1), (' ', 21), ('%', 9), (' ', 21), ('%', 9), (' ', 20), ('\n', 1), (' ', 26), ('%', 29), (' ', 25), ('\n', 1), (' ', 35), ('%', 12), (' ', 33), ('\n', 4)]

# %%
decodeString(encodedString)
# Out:
#                                %%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%                         %%%%%%%%
#                 %%%%%%%                                   %%%%%%
#               %%%%%%                                         %%%%%%
#            %%%%%%                                               %%%%%
#           %%%%%                                                   %%%%%
#         %%%%%                                                       %%%%%
#        %%%%                 %%%%%              %%%%%                  %%%%
#       %%%%                 %%%%%%%            %%%%%%%                  %%%%
#      %%%%                  %%%%%%%            %%%%%%%                   %%%%
#     %%%%                   %%%%%%%            %%%%%%%                    %%%%
#     %%%%                    %%%%%              %%%%%                     %%%%
#    %%%%                                                                   %%%%
#    %%%%                                                                   %%%%
#    %%%%                                                                   %%%%
#    %%%%                                                      %%%%        %%%%
#     %%%%       %%%%%%                                        %%%%%       %%%%
#     %%%%         %%%%                                       %%%%        %%%%
#      %%%%         %%%%                                     %%%%         %%%%
#       %%%%         %%%%%                                  %%%%         %%%%
#        %%%%%         %%%%%                             %%%%%         %%%%%
#         %%%%%          %%%%%%                        %%%%%          %%%%
#           %%%%%           %%%%%%%               %%%%%%%           %%%%%
#             %%%%%             %%%%%%%%%%%%%%%%%%%%%             %%%%%
#               %%%%%%%                                        %%%%%
#                  %%%%%%%                                 %%%%%%%
#                      %%%%%%%%%                     %%%%%%%%%
#                           %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                    %%%%%%%%%%%%
# '\n\n\n\n                               %%%%%%%%%%%%%%%%%%%                              \n                        %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%                       \n                    %%%%%%%%                         %%%%%%%%                   \n                %%%%%%%                                   %%%%%%                \n              %%%%%%                                         %%%%%%             \n           %%%%%%                                               %%%%%           \n          %%%%%                                                   %%%%%         \n        %%%%%                                                       %%%%%       \n       %%%%                 %%%%%              %%%%%                  %%%%      \n      %%%%                 %%%%%%%            %%%%%%%                  %%%%     \n     %%%%                  %%%%%%%            %%%%%%%                   %%%%    \n    %%%%                   %%%%%%%            %%%%%%%                    %%%%   \n    %%%%                    %%%%%              %%%%%                     %%%%   \n   %%%%                                                                   %%%%  \n   %%%%                                                                   %%%%  \n   %%%%                                                                   %%%%  \n   %%%%                                                      %%%%        %%%%   \n    %%%%       %%%%%%                                        %%%%%       %%%%   \n    %%%%         %%%%                                       %%%%        %%%%    \n     %%%%         %%%%                                     %%%%         %%%%    \n      %%%%         %%%%%                                  %%%%         %%%%     \n       %%%%%         %%%%%                             %%%%%         %%%%%      \n        %%%%%          %%%%%%                        %%%%%          %%%%        \n          %%%%%           %%%%%%%               %%%%%%%           %%%%%         \n            %%%%%             %%%%%%%%%%%%%%%%%%%%%             %%%%%           \n              %%%%%%%                                        %%%%%              \n                 %%%%%%%                                 %%%%%%%                \n                     %%%%%%%%%                     %%%%%%%%%                    \n                          %%%%%%%%%%%%%%%%%%%%%%%%%%%%%                         \n                                   %%%%%%%%%%%%                                 \n\n\n\n'
