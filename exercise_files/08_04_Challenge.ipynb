# %% [markdown]
# ## Message Exceptions
#
# The SaveMessages class now has limited memory and should only be able to hold a maximum of 10 messages at once.
#
# This challenge has three parts, outlined in comments below.
#
# **\# 1. Finish creating the TooManyMessagesException class**
#
# Fill in the TooManyMessagesException class. Add a custom message!
#
# **\# 2. Raise a TooManyMessagesException exception here**
#
# Make sure that the SaveMessages class doesn't get over-full and raises an Exception if the max_messages limit is reached.
#
# **\# 3. Catch a TooManyMessagesException and print the messages**
#
# Modify this code so that, if an exception is raised when the message is sent, the messages are printed out (emptying the message list) and the message is re-sent. Make sure to print out any remaining messages at the end!

# %%
from datetime import datetime

def getCurrentTime():
    return datetime.now().strftime("%m-%d-%Y %H:%M:%S")


class Messenger:
    def __init__(self, listeners=[]):
        self.listeners = listeners
    
    def send(self, message):
        for listener in self.listeners:
            listener.receive(message)

    def receive(self, message):
        pass

# 1. Finish creating the TooManyMessagesException class
class TooManyMessagesException(Exception):
     def __init__(self, message, maxMessageCount):
        super().__init__(f'Exception: Too Many Messages! \'{message}\' cannot be added because it exceeded max message count {maxMessageCount}.')

class SaveMessages(Messenger):
    def __init__(self, listeners=[]):
        super().__init__(listeners)
        self.messages = []
        self.max_messages = 10
        
    def receive(self, message):
        if len(self.messages) >= self.max_messages:
            raise TooManyMessagesException(message, self.max_messages)
        
        self.messages.append({'message': message, 'time': getCurrentTime()})
        
    def printMessages(self):
        for m in self.messages:
            print(f'Message: "{m["message"]}" Time: {m["time"]}')
        self.messages = []

# %%
listener = SaveMessages()
sender = Messenger([listener])

# %%
# 3. Catch a TooManyMessagesException and print the messages 
for i in range(0, 20):
    sender.send(f'This is message {i}')
# Out:
# ---------------------------------------------------------------------------
# TooManyMessagesException                  Traceback (most recent call last)
# Cell In[9], line 3
#       1 # 3. Catch a TooManyMessagesException and print the messages
#       2 for i in range(0, 20):
# ----> 3     sender.send(f'This is message {i}')
#
# Cell In[7], line 13, in Messenger.send(self, message)
#      11 def send(self, message):
#      12     for listener in self.listeners:
# ---> 13         listener.receive(message)
#
# Cell In[7], line 31, in SaveMessages.receive(self, message)
#      29 def receive(self, message):
#      30     if len(self.messages) >= self.max_messages:
# ---> 31         raise TooManyMessagesException(message, self.max_messages)
#      33     self.messages.append({'message': message, 'time': getCurrentTime()})
#
# TooManyMessagesException: Exception: Too Many Messages! 'This is message 10' caanot be added because it exceeded max message count 10.
