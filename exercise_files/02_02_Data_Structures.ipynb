# %% [markdown]
# # Data Structures

# %% [markdown]
# ## Lists

# %%
my_list = [1,2,3,4]
print(my_list)
# Out:
# [1, 2, 3, 4]

# %%
my_list = ['list', 'of', 'strings']

# %%
list = [1,'list', False, []]

# %%
my_list = [[1,2,3],[False, True], [], list]
# Out:
# [[1, 2, 3], [False, True], [], [1, 'list', False, []]]

# %%
print(my_list)
# Out:
# [[1, 2, 3], [False, True], [], [1, 'list', False, []]]

# %%
len(my_list)
# Out:
# 4

# %% [markdown]
# ## Sets

# %%
my_set = {1,2,3,4,5}
print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
type(my_set)
# Out:
# set

# %%
len(my_set)
# Out:
# 5

# %%
my_set = {1,1,2,2}
len(my_set)
print(my_set)
# Out:
# {1, 2}

# %%
[1,2] == [2,1]
# Out:
# False

# %%
{1,2,3} == {3,2,1,1,1}
# Out:
# True

# %% [markdown]
# ## Tuples

# %%
my_tuple = (1,2,3)

# %%
len(my_tuple)
# Out:
# 3

# %%
(1,2) == (2,1)
# Out:
# False

# %%
my_list.append(6)
print(my_list)
# Out:
# [[1, 2, 3], [False, True], [], [1, 'list', False, []], 6]

# %%
my_tuple.append(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 my_tuple.append(4)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# ## Dictionaries

# %%
my_dictionary = {
    'apple': 'A red fruit', 
    'bear': 'A scary animal'
}

# %%
my_dictionary['apple']
# Out:
# 'A red fruit'

# %%
my_dictionary = {
    'apple': 'A red fruit', 
    'bear': 'A scary animal',
    'apple': 'Sometimes a green fruit'
}

# %%
my_dictionary['apple']
# Out:
# 'Sometimes a green fruit'
